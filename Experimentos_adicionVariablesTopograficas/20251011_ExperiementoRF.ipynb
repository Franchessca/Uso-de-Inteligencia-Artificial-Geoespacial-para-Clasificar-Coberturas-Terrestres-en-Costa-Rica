# %% [markdown]
# # Modelo RANDOM FOREST

# %%
import time
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_recall_fscore_support, confusion_matrix, classification_report, ConfusionMatrixDisplay
import os

# %%
SEED = 42
ruta_carpeta_actual = os.getcwd()
ruta_carpeta_raiz = os.path.dirname(ruta_carpeta_actual)
csv_path  = os.path.join(ruta_carpeta_raiz, "dataset", "PuntosMuestra_CR_2023_topografia.csv")
df = pd.read_csv(csv_path)
# c:\Users\Fran\Documents\2025-2_Seminario2\Uso-de-Inteligencia-Artificial-Geoespacial-para-Clasificar-Coberturas-Terrestres-en-Costa-Rica\dataset\PuntosMuestra_CR_2023.csv

# %% [markdown]
# ## Limpieza

# %%
# Quitar valores de la CATEGORIA = 2
df_filtrado = df[df["CATEGORIA"] != 2]

y = df_filtrado["CATEGORIA"]
X = df_filtrado.drop(columns=["CATEGORIA", "lon", "lat", "year"])

# %% [markdown]
# ## Dividir entrenamiento y prueba

# %%
SEED = 42

# 1) Split en train 80% / val 10% / test 10% (estratificado)
X_train, X_tmp, y_train, y_tmp = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=SEED)
    
X_val, X_test, y_val, y_test = train_test_split(
    X_tmp, y_tmp, test_size=0.50, stratify=y_tmp, random_state=SEED)

# %% [markdown]
# ## Entrenamiento y medida de tiempo

# %%
import itertools
import matplotlib.pyplot as plt
import seaborn as sns

# Define listas de valores para cada hiperparámetro de RF
# 200, None, 'sqrt', 5, 2, 'balanced'
# Define listas de valores para cada hiperparámetro de RF
n_estimators_list = [100, 200]
max_depth_list    = [None]
max_features_list = ["sqrt"]
min_split_list    = [2, 5]
min_leaf_list     = [1, 2]
class_weight_list = ["balanced"]

mejor_cfg = None
mejor_f1  = -1.0
mejor_rf  = None
grich_n   = 0

for (n_est, max_d, max_f, ms_s, ms_l, cw) in itertools.product(
    n_estimators_list, max_depth_list, max_features_list, min_split_list, min_leaf_list, class_weight_list
):
    grich_n += 1
    print(f"RF Grid {grich_n}: ne={n_est}, md={max_d}, mf={max_f}, mss={ms_s}, msl={ms_l}, cw={cw}")

    rf = RandomForestClassifier(
        n_estimators=n_est,
        max_depth=max_d,
        max_features=max_f,
        min_samples_split=ms_s,
        min_samples_leaf=ms_l,
        class_weight=cw,
        random_state=SEED,
        n_jobs=-1
    )

    # --- ENTRENAR en TRAIN ---
    t0_fit = time.perf_counter()
    rf.fit(X_train, y_train)
    fit_s = time.perf_counter() - t0_fit

    # --- EVALUAR en VALIDACIÓN (para seleccionar mejor config) ---
    t0_pred_val = time.perf_counter()
    y_pred_val = rf.predict(X_val)
    pred_val_s = time.perf_counter() - t0_pred_val
    ms_per_sample_val = (pred_val_s / len(y_val)) * 1000.0

    oa_val = accuracy_score(y_val, y_pred_val)
    prec_val, rec_val, f1m_val, _ = precision_recall_fscore_support(
        y_val, y_pred_val, average="macro", zero_division=0
    )

    print(f"VAL -> OA: {oa_val:.4f} | Prec(macro): {prec_val:.4f} | Recall(macro): {rec_val:.4f} | F1-macro: {f1m_val:.4f} "
          f"| ⏱ pred: {pred_val_s:.3f}s ({ms_per_sample_val:.2f} ms/muestra) | ⏱ fit: {fit_s:.2f}s")
    print("-"*80)

    # --- Guardar mejor por F1 en VALIDACIÓN ---
    if f1m_val > mejor_f1:
        mejor_f1  = f1m_val
        mejor_cfg = (n_est, max_d, max_f, ms_s, ms_l, cw)
        mejor_rf  = rf
        mejor_fit_s_val = fit_s  # guardo fit del mejor por si quieres reportarlo
        mejor_stats_val = (oa_val, prec_val, rec_val, f1m_val)
# Out:
# RF Grid 1: ne=100, md=None, mf=sqrt, mss=2, msl=1, cw=balanced
# VAL -> OA: 0.9153 | Prec(macro): 0.8906 | Recall(macro): 0.8686 | F1-macro: 0.8791 | ⏱ pred: 0.030s (0.01 ms/muestra) | ⏱ fit: 0.47s
# --------------------------------------------------------------------------------
# RF Grid 2: ne=100, md=None, mf=sqrt, mss=2, msl=2, cw=balanced
# VAL -> OA: 0.9167 | Prec(macro): 0.8805 | Recall(macro): 0.8796 | F1-macro: 0.8800 | ⏱ pred: 0.029s (0.01 ms/muestra) | ⏱ fit: 0.44s
# --------------------------------------------------------------------------------
# RF Grid 3: ne=100, md=None, mf=sqrt, mss=5, msl=1, cw=balanced
# VAL -> OA: 0.9150 | Prec(macro): 0.8834 | Recall(macro): 0.8764 | F1-macro: 0.8798 | ⏱ pred: 0.029s (0.01 ms/muestra) | ⏱ fit: 0.43s
# --------------------------------------------------------------------------------
# RF Grid 4: ne=100, md=None, mf=sqrt, mss=5, msl=2, cw=balanced
# ...

# %%
print(f"\nMejor configuración (por F1 en VAL): {mejor_cfg} | F1_val={mejor_f1:.4f}")

t0_pred_test = time.perf_counter()
y_pred_test = mejor_rf.predict(X_test)
pred_test_s = time.perf_counter() - t0_pred_test
ms_per_sample_test = (pred_test_s / len(y_test)) * 1000.0

oa_test = accuracy_score(y_test, y_pred_test)
prec_test, rec_test, f1m_test, _ = precision_recall_fscore_support(
    y_test, y_pred_test, average="macro", zero_division=0
)

cm_test = confusion_matrix(y_test, y_pred_test)
cm_test_per = cm_test.astype(float) / cm_test.sum(axis=1, keepdims=True) * 100.0
cm_test_per = np.nan_to_num(cm_test_per)

print(f"\nTEST -> OA: {oa_test:.4f} | Prec(macro): {prec_test:.4f} | Recall(macro): {rec_test:.4f} | F1-macro: {f1m_test:.4f}")
print(f"⏱ pred: {pred_test_s:.3f}s ({ms_per_sample_test:.2f} ms/muestra)")
print("\nReporte por clase (TEST):\n", classification_report(y_test, y_pred_test, digits=4))

# Matriz de confusión (absoluta)
ConfusionMatrixDisplay(cm_test).plot(cmap='Blues')
plt.title("Matriz de confusión - Random Forest (Test)")
plt.tight_layout(); plt.show()

# Matriz de confusión (% por fila)
ConfusionMatrixDisplay(cm_test_per).plot(cmap='Blues', colorbar=False)
plt.title("Matriz de confusión (%) - Random Forest (Test)")
plt.tight_layout(); plt.show()
# Out:
# Mejor configuración (por F1 en VAL): (100, None, 'sqrt', 5, 2, 'balanced') | F1_val=0.8823
#
# TEST -> OA: 0.9174 | Prec(macro): 0.8882 | Recall(macro): 0.8836 | F1-macro: 0.8852
# ⏱ pred: 0.031s (0.01 ms/muestra)
#
# Reporte por clase (TEST):
#                precision    recall  f1-score   support
#
#            1     0.9298    0.9207    0.9252       820
#            3     0.9333    0.9395    0.9364      1520
#            4     0.9304    0.9554    0.9427       112
#            6     0.8430    0.8644    0.8536       118
#            7     0.8760    0.7737    0.8217       137
#           10     0.8165    0.8476    0.8318       210
#
#     accuracy                         0.9174      2917
#    macro avg     0.8882    0.8836    0.8852      2917
# weighted avg     0.9175    0.9174    0.9172      2917
