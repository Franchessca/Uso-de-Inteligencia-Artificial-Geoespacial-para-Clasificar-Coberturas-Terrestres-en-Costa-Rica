# %% [markdown]
# # Modelo XGBoost

# %%
import time
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_recall_fscore_support, confusion_matrix, classification_report, ConfusionMatrixDisplay
from xgboost import XGBClassifier
import os

# %%
SEED = 42
ruta_carpeta_actual = os.getcwd()
ruta_carpeta_raiz = os.path.dirname(ruta_carpeta_actual)
csv_path  = os.path.join(ruta_carpeta_raiz, "dataset", "PuntosMuestra_CR_2023_topografia.csv")
df = pd.read_csv(csv_path)

# %% [markdown]
# ## Limpieza

# %%
# Eliminar CATEGORIA = 2
df_filtrado = df[df['CATEGORIA'] != 2].copy()

# Remapear categorías a consecutivas 0..K-1
clases_unicas = sorted(df_filtrado["CATEGORIA"].unique())
mapa = {old: new for new, old in enumerate(clases_unicas)}
df_filtrado["CATEGORIA"] = df_filtrado["CATEGORIA"].map(mapa)

y = df_filtrado["CATEGORIA"]
X = df_filtrado.drop(columns=["CATEGORIA", "lon", "lat", "year"])

# %% [markdown]
# ## Definir modelo XGBoost

# %% [markdown]
# ### Division de data test y prueba

# %%
SEED = 42

# 1) Split en train 80% / val 10% / test 10% (estratificado)
X_train, X_tmp, y_train, y_tmp = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=SEED)
    
X_val, X_test, y_val, y_test = train_test_split(
    X_tmp, y_tmp, test_size=0.50, stratify=y_tmp, random_state=SEED)

# %% [markdown]
# ### Entrenamiento

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

# --- ajustar en caso haya CUDA y xgboost con soporte GPU ---
use_gpu = False  # True si quieres intentar GPU

# === Grid de hiperparámetros XGBoost ===
n_estimators_list     = [100, 200]
max_depth_list        = [4, 6]
learning_rate_list    = [0.05, 0.1]
subsample_list        = [0.8, 1.0]
colsample_bytree_list = [0.8, 1.0]

mejor_cfg   = None
mejor_f1val = -1.0
mejor_xgb   = None
mejor_grich = None
grich_n     = 0

for n_est, md, lr, subs, colsb in itertools.product(
        n_estimators_list, max_depth_list, learning_rate_list, subsample_list, colsample_bytree_list):

    grich_n += 1
    cfg = dict(n_estimators=n_est, max_depth=md, learning_rate=lr,
               subsample=subs, colsample_bytree=colsb)
    print(f"XGB Grid {grich_n}: {cfg}")

    xgb = XGBClassifier(
        n_estimators=n_est,
        max_depth=md,
        learning_rate=lr,
        subsample=subs,
        colsample_bytree=colsb,
        objective="multi:softprob",
        eval_metric="mlogloss",
        tree_method="gpu_hist" if use_gpu else "hist",
        n_jobs=-1,
        random_state=SEED,
    )

    # --- ENTRENAR en TRAIN ---
    t0_fit = time.perf_counter()
    xgb.fit(X_train, y_train, verbose=False)
    fit_s = time.perf_counter() - t0_fit

    # --- VALIDACIÓN para SELECCIÓN ---
    t0_pred_val = time.perf_counter()
    y_pred_val  = xgb.predict(X_val)
    pred_val_s  = time.perf_counter() - t0_pred_val
    ms_per_val  = (pred_val_s / len(y_val)) * 1000.0

    oa_val   = accuracy_score(y_val, y_pred_val)
    prec_val, rec_val, f1m_val, _ = precision_recall_fscore_support(
        y_val, y_pred_val, average="macro", zero_division=0
    )

    print(f"VAL -> OA:{oa_val:.4f} | Prec(macro):{prec_val:.4f} | Recall(macro):{rec_val:.4f} | F1-macro:{f1m_val:.4f} "
          f"| ⏱ pred:{pred_val_s:.3f}s ({ms_per_val:.2f} ms/muestra) | ⏱ fit:{fit_s:.2f}s")
    print("-"*80)

    # --- Guardar mejor por F1 en VALIDACIÓN ---
    if f1m_val > mejor_f1val:
        mejor_f1val = f1m_val
        mejor_cfg   = cfg.copy()
        mejor_xgb   = xgb
        mejor_grich = grich_n
        mejor_fit_s_val = fit_s  # opcional: por si quieres reportarlo
# Out:
# XGB Grid 1: {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.05, 'subsample': 0.8, 'colsample_bytree': 0.8}
# VAL -> OA:0.9036 | Prec(macro):0.8872 | Recall(macro):0.8627 | F1-macro:0.8745 | ⏱ pred:0.003s (0.00 ms/muestra) | ⏱ fit:0.64s
# --------------------------------------------------------------------------------
# XGB Grid 2: {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.05, 'subsample': 0.8, 'colsample_bytree': 1.0}
# VAL -> OA:0.9026 | Prec(macro):0.8843 | Recall(macro):0.8680 | F1-macro:0.8756 | ⏱ pred:0.003s (0.00 ms/muestra) | ⏱ fit:0.38s
# --------------------------------------------------------------------------------
# XGB Grid 3: {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.05, 'subsample': 1.0, 'colsample_bytree': 0.8}
# VAL -> OA:0.9036 | Prec(macro):0.8852 | Recall(macro):0.8635 | F1-macro:0.8739 | ⏱ pred:0.002s (0.00 ms/muestra) | ⏱ fit:0.35s
# --------------------------------------------------------------------------------
# ...

# %%
print(f"\nMejor configuración Grid {mejor_grich}: {mejor_cfg} | F1_val: {mejor_f1val:.4f}")

t0_pred_test = time.perf_counter()
y_pred_test  = mejor_xgb.predict(X_test)
pred_test_s  = time.perf_counter() - t0_pred_test
ms_per_test  = (pred_test_s / len(y_test)) * 1000.0

oa_test = accuracy_score(y_test, y_pred_test)
prec_test, rec_test, f1m_test, _ = precision_recall_fscore_support(
    y_test, y_pred_test, average="macro", zero_division=0
)
cm_test = confusion_matrix(y_test, y_pred_test)
cm_test_per = cm_test.astype(float) / cm_test.sum(axis=1, keepdims=True) * 100.0
cm_test_per = np.nan_to_num(cm_test_per)

print(f"TEST -> OA:{oa_test:.4f} | Prec(macro):{prec_test:.4f} | Recall(macro):{rec_test:.4f} | F1-macro:{f1m_test:.4f}")
print(f"⏱ Test:{pred_test_s:.3f}s ({ms_per_test:.2f} ms/muestra)")
print("\nReporte por clase (TEST):\n", classification_report(y_test, y_pred_test, digits=4))

# Matriz de confusión (conteos)
ConfusionMatrixDisplay(cm_test).plot(cmap='Blues')
plt.title("Matriz de confusión - XGBoost (Test)")
plt.tight_layout(); plt.show()

# Matriz de confusión (% por fila)
ConfusionMatrixDisplay(cm_test_per).plot(cmap='Blues', colorbar=False)
plt.title("Matriz de confusión (%) - XGBoost (Test)")
plt.tight_layout(); plt.show()
# Out:
# Mejor configuración Grid 31: {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.1, 'subsample': 1.0, 'colsample_bytree': 0.8} | F1_val: 0.9023
# TEST -> OA:0.9297 | Prec(macro):0.9060 | Recall(macro):0.8840 | F1-macro:0.8939
# ⏱ Test:0.005s (0.00 ms/muestra)
#
# Reporte por clase (TEST):
#                precision    recall  f1-score   support
#
#            0     0.9511    0.9488    0.9499       820
#            1     0.9385    0.9539    0.9462      1520
#            2     0.9643    0.9643    0.9643       112
#            3     0.8655    0.8729    0.8692       118
#            4     0.9043    0.7591    0.8254       137
#            5     0.8125    0.8048    0.8086       210
#
#     accuracy                         0.9297      2917
#    macro avg     0.9060    0.8840    0.8939      2917
# weighted avg     0.9294    0.9297    0.9292      2917
